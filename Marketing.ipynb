# %%
import pyodbc
import pandas as pd
from sqlalchemy import create_engine
import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer

# %%
# Download the VADER lexicon for sentiment analysis if not already present.
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\braya\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# True

# %%
# Establecer la conexión a la base de datos
'''def fetch_data_from_sql():
    try:
        connection = pyodbc.connect('DRIVER={SQL Server};SERVER=bvilla;DATABASE=Marketing')
        print("Conexión exitosa.")
        
        # Usar pandas para leer los datos directamente desde SQL
        query = "SELECT * FROM customers"
        df = pd.read_sql(query, connection)
        
        # Mostrar los resultados
        print(df)
        
    except Exception as ex:
        print("Error durante la conexión: {}".format(ex))
    
    finally:
        connection.close()  # Se cierra la conexión a la BD
        print("La conexión ha finalizado.")
'''

# %%
# Aumentar el número de columnas que se pueden mostrar
pd.set_option('display.max_columns', None)

# Aumentar el ancho de las columnas
pd.set_option('display.max_colwidth', None)

# %%
def fetch_data_from_sql():
    # Crear la cadena de conexión usando SQLAlchemy
    DATABASE_CONNECTION = 'mssql+pyodbc://bvilla/Marketing?driver=ODBC+Driver+17+for+SQL+Server'
    
    # Crear el motor de la base de datos
    engine = create_engine(DATABASE_CONNECTION)
    
    # Usar pandas para leer los datos directamente desde SQL
    try:
        query = "SELECT ReviewID, CustomerID, ProductID, ReviewDate, Rating, ReviewText FROM customer_reviews"
        df = pd.read_sql(query, engine)
        
    except Exception as ex:
        print(f"Error durante la conexión: {ex}")
    return df

# %%
customer_reviews_df = fetch_data_from_sql()
customer_reviews_df.head(10)
# Out:
#    ReviewID  CustomerID  ProductID  ReviewDate  Rating  \
# 0         1          77         18  2023-12-23       3
# 1         2          80         19  2024-12-25       5
# 2         3          50         13  2025-01-26       4
# 3         4          78         15  2025-04-21       3
# 4         5          64          2  2023-07-16       3
# 5         6          81          1  2025-12-21       4
# 6         7          16          1  2024-01-29       3
# 7         8          55          8  2024-08-15       5
# 8         9           3         13  2023-09-01       4
# 9        10          78          6  2024-06-17       5
#
#                                    ReviewText
# 0     Average  experience,  nothing  special.
# 1              The  quality  is    top-notch.
# 2     Five  stars  for  the  quick  delivery.
# 3    Good  quality,  but  could  be  cheaper.
# 4     Average  experience,  nothing  special.
# 5      Customer  support  was  very  helpful.
# 6     Average  experience,  nothing  special.
# 7              The  quality    is  top-notch.
# 8  I  love  this  product,  will  buy  again!
# 9     Excellent  product,  highly  recommend!

# %%
# Initialize the VADER sentiment intensity analyzer for analyzing the sentiment of text data
sia = SentimentIntensityAnalyzer()

# %%
# Define a function to calculate sentiment scores using VADER
def calculate_sentiment(review):
    # Get the sentiment scores for the review text
    sentiment = sia.polarity_scores(review)
    # Return the compound score, which is a normalized score between -1 (most negative) and 1 (most positive)
    return sentiment['compound']

# %%
# Apply sentiment analysis to calculate sentiment scores for each review
customer_reviews_df['SentimentScore'] = customer_reviews_df['ReviewText'].apply(calculate_sentiment)
customer_reviews_df.head(50)
# Out:
#     ReviewID  CustomerID  ProductID  ReviewDate  Rating  \
# 0          1          77         18  2023-12-23       3
# 1          2          80         19  2024-12-25       5
# 2          3          50         13  2025-01-26       4
# 3          4          78         15  2025-04-21       3
# 4          5          64          2  2023-07-16       3
# 5          6          81          1  2025-12-21       4
# 6          7          16          1  2024-01-29       3
# 7          8          55          8  2024-08-15       5
# 8          9           3         13  2023-09-01       4
# 9         10          78          6  2024-06-17       5
# 10        11          54          9  2023-07-17       4
# 11        12          77          2  2025-01-13       2
# 12        13          93          6  2024-08-20       5
# 13        14          23          2  2025-06-16       4
# 14        15          29         11  2023-01-27       5
# 15        16          95         17  2023-01-06       5
# 16        17          88          4  2025-10-29       3
# 17        18          17         16  2024-11-23       4
# 18        19          34         13  2024-01-04       4
# 19        20          34          6  2023-04-29       1
# 20        21          22         15  2023-04-08       5
# 21        22          52          3  2025-10-30       4
# 22        23          69         18  2023-07-02       5
# 23        24         100          4  2025-07-18       3
# 24        25          55         20  2024-12-19       4
# 25        26          76         11  2024-08-21       4
# 26        27          56          6  2025-11-24       4
# 27        28          76          8  2025-05-27       5
# 28        29          38         13  2023-05-31       4
# 29        30          84          6  2024-03-18       4
# 30        31          93          4  2025-08-25       3
# 31        32          91          1  2023-07-15       4
# 32        33          30          2  2023-02-21       4
# 33        34          81         15  2024-03-30       5
# 34        35          27         12  2024-03-13       3
# 35        36          96          9  2025-12-05       3
# 36        37          38          3  2023-09-11       3
# 37        38          45         17  2024-05-07       5
# 38        39          54          1  2023-10-02       5
# 39        40          33          2  2025-01-03       5
# 40        41          93         17  2025-05-15       3
# 41        42          72         15  2023-03-21       5
# 42        43          84         15  2025-02-02       4
# 43        44          44         17  2023-04-20       5
# 44        45          11         16  2023-03-23       3
# 45        46          27          5  2025-05-07       4
# 46        47          19         13  2024-06-01       4
# 47        48          70         17  2023-10-08       4
# 48        49           3          7  2025-06-09       3
# 49        50          62          4  2023-01-07       1
#
#                                                     ReviewText  SentimentScore
# 0                      Average  experience,  nothing  special.         -0.3089
# 1                               The  quality  is    top-notch.          0.0000
# 2                      Five  stars  for  the  quick  delivery.          0.0000
# 3                     Good  quality,  but  could  be  cheaper.          0.2382
# 4                      Average  experience,  nothing  special.         -0.3089
# 5                       Customer  support  was  very  helpful.          0.6997
# 6                      Average  experience,  nothing  special.         -0.3089
# 7                               The  quality    is  top-notch.          0.0000
# 8                   I  love  this  product,  will  buy  again!          0.6696
# 9                      Excellent  product,  highly  recommend!          0.7773
# 10                          Great  purchase,  very  satisfied.          0.8016
# 11                Product  did    not  meet  my  expectations.          0.0000
# 12                          Great  purchase,  very  satisfied.          0.8016
# 13                    Good  quality,  but  could  be  cheaper.          0.2382
# 14                          Great  purchase,  very  satisfied.          0.8016
# 15                     Excellent  product,  highly  recommend!          0.7773
# 16                                     Not  worth  the  money.         -0.1695
# 17    Shipping  was  fast  and  the  item  was  well-packaged.          0.0000
# 18                                The  quality  is  top-notch.          0.0000
# 19            I  had  a  bad  experience  with  this  product.         -0.5423
# 20                            Amazing  value  for  the  price.          0.7351
# 21                                The  quality  is  top-notch.          0.0000
# 22                     Five  stars  for  the  quick  delivery.          0.0000
# 23                I  love  this    product,  will  buy  again!          0.6696
# 24    Shipping  was  fast  and  the  item  was  well-packaged.          0.0000
# 25                     Five  stars  for  the  quick  delivery.          0.0000
# 26                                The  quality  is  top-notch.          0.0000
# 27                     Five  stars  for  the  quick  delivery.          0.0000
# 28                  I  love  this  product,  will  buy  again!          0.6696
# 29                     Five  stars  for  the  quick  delivery.          0.0000
# 30                  Good  quality,  but  could  be    cheaper.          0.2382
# 31                                The  quality  is  top-notch.          0.0000
# 32    Shipping  was  fast  and  the  item  was  well-packaged.          0.0000
# 33                     Excellent  product,  highly  recommend!          0.7773
# 34                     Average  experience,  nothing  special.         -0.3089
# 35                    Good  quality,  but  could  be  cheaper.          0.2382
# 36                   Average  experience,  nothing    special.         -0.3089
# 37                          Great  purchase,  very  satisfied.          0.8016
# 38                      Customer  support  was  very  helpful.          0.6997
# 39                   Five  stars    for  the  quick  delivery.          0.0000
# 40                     Average  experience,  nothing  special.         -0.3089
# 41                     Five  stars  for  the  quick  delivery.          0.0000
# 42                               Exceeded  my    expectations!          0.0000
# 43                   Excellent  product,    highly  recommend!          0.7773
# 44                                     Not  worth  the  money.         -0.1695
# 45                     Five  stars  for  the  quick  delivery.          0.0000
# 46                     Five  stars  for  the  quick  delivery.          0.0000
# 47  Shipping  was  fast  and  the  item    was  well-packaged.          0.0000
# 48                  Good  quality,  but  could    be  cheaper.          0.2382
# 49            The  product  stopped  working  after  a  month.         -0.2263

# %%
# Define a function to categorize sentiment using both the sentiment score and the review rating
def categorize_sentiment(score, rating):
    # Use both the text sentiment score and the numerical rating to determine sentiment category
    if score > 0.05:  # Positive sentiment score
        if rating >= 4:
            return 'Positive'  # High rating and positive sentiment
        elif rating == 3:
            return 'Mixed Positive'  # Neutral rating but positive sentiment
        else:
            return 'Mixed Negative'  # Low rating but positive sentiment
    elif score < -0.05:  # Negative sentiment score
        if rating <= 2:
            return 'Negative'  # Low rating and negative sentiment
        elif rating == 3:
            return 'Mixed Negative'  # Neutral rating but negative sentiment
        else:
            return 'Mixed Positive'  # High rating but negative sentiment
    else:  # Neutral sentiment score
        if rating >= 4:
            return 'Positive'  # High rating with neutral sentiment
        elif rating <= 2:
            return 'Negative'  # Low rating with neutral sentiment
        else:
            return 'Neutral'  # Neutral rating and neutral sentiment

# %%
# Apply sentiment categorization using both text and rating
customer_reviews_df['SentimentCategory'] = customer_reviews_df.apply(
    lambda row: categorize_sentiment(row['SentimentScore'], row['Rating']), axis=1)
customer_reviews_df.head(50)
# Out:
#     ReviewID  CustomerID  ProductID  ReviewDate  Rating  \
# 0          1          77         18  2023-12-23       3
# 1          2          80         19  2024-12-25       5
# 2          3          50         13  2025-01-26       4
# 3          4          78         15  2025-04-21       3
# 4          5          64          2  2023-07-16       3
# 5          6          81          1  2025-12-21       4
# 6          7          16          1  2024-01-29       3
# 7          8          55          8  2024-08-15       5
# 8          9           3         13  2023-09-01       4
# 9         10          78          6  2024-06-17       5
# 10        11          54          9  2023-07-17       4
# 11        12          77          2  2025-01-13       2
# 12        13          93          6  2024-08-20       5
# 13        14          23          2  2025-06-16       4
# 14        15          29         11  2023-01-27       5
# 15        16          95         17  2023-01-06       5
# 16        17          88          4  2025-10-29       3
# 17        18          17         16  2024-11-23       4
# 18        19          34         13  2024-01-04       4
# 19        20          34          6  2023-04-29       1
# 20        21          22         15  2023-04-08       5
# 21        22          52          3  2025-10-30       4
# 22        23          69         18  2023-07-02       5
# 23        24         100          4  2025-07-18       3
# 24        25          55         20  2024-12-19       4
# 25        26          76         11  2024-08-21       4
# 26        27          56          6  2025-11-24       4
# 27        28          76          8  2025-05-27       5
# 28        29          38         13  2023-05-31       4
# 29        30          84          6  2024-03-18       4
# 30        31          93          4  2025-08-25       3
# 31        32          91          1  2023-07-15       4
# 32        33          30          2  2023-02-21       4
# 33        34          81         15  2024-03-30       5
# 34        35          27         12  2024-03-13       3
# 35        36          96          9  2025-12-05       3
# 36        37          38          3  2023-09-11       3
# 37        38          45         17  2024-05-07       5
# 38        39          54          1  2023-10-02       5
# 39        40          33          2  2025-01-03       5
# 40        41          93         17  2025-05-15       3
# 41        42          72         15  2023-03-21       5
# 42        43          84         15  2025-02-02       4
# 43        44          44         17  2023-04-20       5
# 44        45          11         16  2023-03-23       3
# 45        46          27          5  2025-05-07       4
# 46        47          19         13  2024-06-01       4
# 47        48          70         17  2023-10-08       4
# 48        49           3          7  2025-06-09       3
# 49        50          62          4  2023-01-07       1
#
#                                                     ReviewText  \
# 0                      Average  experience,  nothing  special.
# 1                               The  quality  is    top-notch.
# 2                      Five  stars  for  the  quick  delivery.
# 3                     Good  quality,  but  could  be  cheaper.
# 4                      Average  experience,  nothing  special.
# 5                       Customer  support  was  very  helpful.
# 6                      Average  experience,  nothing  special.
# 7                               The  quality    is  top-notch.
# 8                   I  love  this  product,  will  buy  again!
# 9                      Excellent  product,  highly  recommend!
# 10                          Great  purchase,  very  satisfied.
# 11                Product  did    not  meet  my  expectations.
# 12                          Great  purchase,  very  satisfied.
# 13                    Good  quality,  but  could  be  cheaper.
# 14                          Great  purchase,  very  satisfied.
# 15                     Excellent  product,  highly  recommend!
# 16                                     Not  worth  the  money.
# 17    Shipping  was  fast  and  the  item  was  well-packaged.
# 18                                The  quality  is  top-notch.
# 19            I  had  a  bad  experience  with  this  product.
# 20                            Amazing  value  for  the  price.
# 21                                The  quality  is  top-notch.
# 22                     Five  stars  for  the  quick  delivery.
# 23                I  love  this    product,  will  buy  again!
# 24    Shipping  was  fast  and  the  item  was  well-packaged.
# 25                     Five  stars  for  the  quick  delivery.
# 26                                The  quality  is  top-notch.
# 27                     Five  stars  for  the  quick  delivery.
# 28                  I  love  this  product,  will  buy  again!
# 29                     Five  stars  for  the  quick  delivery.
# 30                  Good  quality,  but  could  be    cheaper.
# 31                                The  quality  is  top-notch.
# 32    Shipping  was  fast  and  the  item  was  well-packaged.
# 33                     Excellent  product,  highly  recommend!
# 34                     Average  experience,  nothing  special.
# 35                    Good  quality,  but  could  be  cheaper.
# 36                   Average  experience,  nothing    special.
# 37                          Great  purchase,  very  satisfied.
# 38                      Customer  support  was  very  helpful.
# 39                   Five  stars    for  the  quick  delivery.
# 40                     Average  experience,  nothing  special.
# 41                     Five  stars  for  the  quick  delivery.
# 42                               Exceeded  my    expectations!
# 43                   Excellent  product,    highly  recommend!
# 44                                     Not  worth  the  money.
# 45                     Five  stars  for  the  quick  delivery.
# 46                     Five  stars  for  the  quick  delivery.
# 47  Shipping  was  fast  and  the  item    was  well-packaged.
# 48                  Good  quality,  but  could    be  cheaper.
# 49            The  product  stopped  working  after  a  month.
#
#     SentimentScore SentimentCategory
# 0          -0.3089    Mixed Negative
# 1           0.0000          Positive
# 2           0.0000          Positive
# 3           0.2382    Mixed Positive
# 4          -0.3089    Mixed Negative
# 5           0.6997          Positive
# 6          -0.3089    Mixed Negative
# 7           0.0000          Positive
# 8           0.6696          Positive
# 9           0.7773          Positive
# 10          0.8016          Positive
# 11          0.0000          Negative
# 12          0.8016          Positive
# 13          0.2382          Positive
# 14          0.8016          Positive
# 15          0.7773          Positive
# 16         -0.1695    Mixed Negative
# 17          0.0000          Positive
# 18          0.0000          Positive
# 19         -0.5423          Negative
# 20          0.7351          Positive
# 21          0.0000          Positive
# 22          0.0000          Positive
# 23          0.6696    Mixed Positive
# 24          0.0000          Positive
# 25          0.0000          Positive
# 26          0.0000          Positive
# 27          0.0000          Positive
# 28          0.6696          Positive
# 29          0.0000          Positive
# 30          0.2382    Mixed Positive
# 31          0.0000          Positive
# 32          0.0000          Positive
# 33          0.7773          Positive
# 34         -0.3089    Mixed Negative
# 35          0.2382    Mixed Positive
# 36         -0.3089    Mixed Negative
# 37          0.8016          Positive
# 38          0.6997          Positive
# 39          0.0000          Positive
# 40         -0.3089    Mixed Negative
# 41          0.0000          Positive
# 42          0.0000          Positive
# 43          0.7773          Positive
# 44         -0.1695    Mixed Negative
# 45          0.0000          Positive
# 46          0.0000          Positive
# 47          0.0000          Positive
# 48          0.2382    Mixed Positive
# 49         -0.2263          Negative

# %%
# Define a function to bucket sentiment scores into text ranges
def sentiment_bucket(score):
    if score >= 0.5:
        return '0.5 to 1.0'  # Strongly positive sentiment
    elif 0.0 <= score < 0.5:
        return '0.0 to 0.49'  # Mildly positive sentiment
    elif -0.5 <= score < 0.0:
        return '-0.49 to 0.0'  # Mildly negative sentiment
    else:
        return '-1.0 to -0.5'  # Strongly negative sentiment

# %%
# Apply sentiment bucketing to categorize scores into defined ranges
customer_reviews_df['SentimentBucket'] = customer_reviews_df['SentimentScore'].apply(sentiment_bucket)
customer_reviews_df.head(50)
# Out:
#     ReviewID  CustomerID  ProductID  ReviewDate  Rating  \
# 0          1          77         18  2023-12-23       3
# 1          2          80         19  2024-12-25       5
# 2          3          50         13  2025-01-26       4
# 3          4          78         15  2025-04-21       3
# 4          5          64          2  2023-07-16       3
# 5          6          81          1  2025-12-21       4
# 6          7          16          1  2024-01-29       3
# 7          8          55          8  2024-08-15       5
# 8          9           3         13  2023-09-01       4
# 9         10          78          6  2024-06-17       5
# 10        11          54          9  2023-07-17       4
# 11        12          77          2  2025-01-13       2
# 12        13          93          6  2024-08-20       5
# 13        14          23          2  2025-06-16       4
# 14        15          29         11  2023-01-27       5
# 15        16          95         17  2023-01-06       5
# 16        17          88          4  2025-10-29       3
# 17        18          17         16  2024-11-23       4
# 18        19          34         13  2024-01-04       4
# 19        20          34          6  2023-04-29       1
# 20        21          22         15  2023-04-08       5
# 21        22          52          3  2025-10-30       4
# 22        23          69         18  2023-07-02       5
# 23        24         100          4  2025-07-18       3
# 24        25          55         20  2024-12-19       4
# 25        26          76         11  2024-08-21       4
# 26        27          56          6  2025-11-24       4
# 27        28          76          8  2025-05-27       5
# 28        29          38         13  2023-05-31       4
# 29        30          84          6  2024-03-18       4
# 30        31          93          4  2025-08-25       3
# 31        32          91          1  2023-07-15       4
# 32        33          30          2  2023-02-21       4
# 33        34          81         15  2024-03-30       5
# 34        35          27         12  2024-03-13       3
# 35        36          96          9  2025-12-05       3
# 36        37          38          3  2023-09-11       3
# 37        38          45         17  2024-05-07       5
# 38        39          54          1  2023-10-02       5
# 39        40          33          2  2025-01-03       5
# 40        41          93         17  2025-05-15       3
# 41        42          72         15  2023-03-21       5
# 42        43          84         15  2025-02-02       4
# 43        44          44         17  2023-04-20       5
# 44        45          11         16  2023-03-23       3
# 45        46          27          5  2025-05-07       4
# 46        47          19         13  2024-06-01       4
# 47        48          70         17  2023-10-08       4
# 48        49           3          7  2025-06-09       3
# 49        50          62          4  2023-01-07       1
#
#                                                     ReviewText  \
# 0                      Average  experience,  nothing  special.
# 1                               The  quality  is    top-notch.
# 2                      Five  stars  for  the  quick  delivery.
# 3                     Good  quality,  but  could  be  cheaper.
# 4                      Average  experience,  nothing  special.
# 5                       Customer  support  was  very  helpful.
# 6                      Average  experience,  nothing  special.
# 7                               The  quality    is  top-notch.
# 8                   I  love  this  product,  will  buy  again!
# 9                      Excellent  product,  highly  recommend!
# 10                          Great  purchase,  very  satisfied.
# 11                Product  did    not  meet  my  expectations.
# 12                          Great  purchase,  very  satisfied.
# 13                    Good  quality,  but  could  be  cheaper.
# 14                          Great  purchase,  very  satisfied.
# 15                     Excellent  product,  highly  recommend!
# 16                                     Not  worth  the  money.
# 17    Shipping  was  fast  and  the  item  was  well-packaged.
# 18                                The  quality  is  top-notch.
# 19            I  had  a  bad  experience  with  this  product.
# 20                            Amazing  value  for  the  price.
# 21                                The  quality  is  top-notch.
# 22                     Five  stars  for  the  quick  delivery.
# 23                I  love  this    product,  will  buy  again!
# 24    Shipping  was  fast  and  the  item  was  well-packaged.
# 25                     Five  stars  for  the  quick  delivery.
# 26                                The  quality  is  top-notch.
# 27                     Five  stars  for  the  quick  delivery.
# 28                  I  love  this  product,  will  buy  again!
# 29                     Five  stars  for  the  quick  delivery.
# 30                  Good  quality,  but  could  be    cheaper.
# 31                                The  quality  is  top-notch.
# 32    Shipping  was  fast  and  the  item  was  well-packaged.
# 33                     Excellent  product,  highly  recommend!
# 34                     Average  experience,  nothing  special.
# 35                    Good  quality,  but  could  be  cheaper.
# 36                   Average  experience,  nothing    special.
# 37                          Great  purchase,  very  satisfied.
# 38                      Customer  support  was  very  helpful.
# 39                   Five  stars    for  the  quick  delivery.
# 40                     Average  experience,  nothing  special.
# 41                     Five  stars  for  the  quick  delivery.
# 42                               Exceeded  my    expectations!
# 43                   Excellent  product,    highly  recommend!
# 44                                     Not  worth  the  money.
# 45                     Five  stars  for  the  quick  delivery.
# 46                     Five  stars  for  the  quick  delivery.
# 47  Shipping  was  fast  and  the  item    was  well-packaged.
# 48                  Good  quality,  but  could    be  cheaper.
# 49            The  product  stopped  working  after  a  month.
#
#     SentimentScore SentimentCategory SentimentBucket
# 0          -0.3089    Mixed Negative    -0.49 to 0.0
# 1           0.0000          Positive     0.0 to 0.49
# 2           0.0000          Positive     0.0 to 0.49
# 3           0.2382    Mixed Positive     0.0 to 0.49
# 4          -0.3089    Mixed Negative    -0.49 to 0.0
# 5           0.6997          Positive      0.5 to 1.0
# 6          -0.3089    Mixed Negative    -0.49 to 0.0
# 7           0.0000          Positive     0.0 to 0.49
# 8           0.6696          Positive      0.5 to 1.0
# 9           0.7773          Positive      0.5 to 1.0
# 10          0.8016          Positive      0.5 to 1.0
# 11          0.0000          Negative     0.0 to 0.49
# 12          0.8016          Positive      0.5 to 1.0
# 13          0.2382          Positive     0.0 to 0.49
# 14          0.8016          Positive      0.5 to 1.0
# 15          0.7773          Positive      0.5 to 1.0
# 16         -0.1695    Mixed Negative    -0.49 to 0.0
# 17          0.0000          Positive     0.0 to 0.49
# 18          0.0000          Positive     0.0 to 0.49
# 19         -0.5423          Negative    -1.0 to -0.5
# 20          0.7351          Positive      0.5 to 1.0
# 21          0.0000          Positive     0.0 to 0.49
# 22          0.0000          Positive     0.0 to 0.49
# 23          0.6696    Mixed Positive      0.5 to 1.0
# 24          0.0000          Positive     0.0 to 0.49
# 25          0.0000          Positive     0.0 to 0.49
# 26          0.0000          Positive     0.0 to 0.49
# 27          0.0000          Positive     0.0 to 0.49
# 28          0.6696          Positive      0.5 to 1.0
# 29          0.0000          Positive     0.0 to 0.49
# 30          0.2382    Mixed Positive     0.0 to 0.49
# 31          0.0000          Positive     0.0 to 0.49
# 32          0.0000          Positive     0.0 to 0.49
# 33          0.7773          Positive      0.5 to 1.0
# 34         -0.3089    Mixed Negative    -0.49 to 0.0
# 35          0.2382    Mixed Positive     0.0 to 0.49
# 36         -0.3089    Mixed Negative    -0.49 to 0.0
# 37          0.8016          Positive      0.5 to 1.0
# 38          0.6997          Positive      0.5 to 1.0
# 39          0.0000          Positive     0.0 to 0.49
# 40         -0.3089    Mixed Negative    -0.49 to 0.0
# 41          0.0000          Positive     0.0 to 0.49
# 42          0.0000          Positive     0.0 to 0.49
# 43          0.7773          Positive      0.5 to 1.0
# 44         -0.1695    Mixed Negative    -0.49 to 0.0
# 45          0.0000          Positive     0.0 to 0.49
# 46          0.0000          Positive     0.0 to 0.49
# 47          0.0000          Positive     0.0 to 0.49
# 48          0.2382    Mixed Positive     0.0 to 0.49
# 49         -0.2263          Negative    -0.49 to 0.0

# %%
# Save the DataFrame with sentiment scores, categories, and buckets to a new CSV file
customer_reviews_df.to_csv('fact_customer_reviews_with_sentiment.csv', index=False)
